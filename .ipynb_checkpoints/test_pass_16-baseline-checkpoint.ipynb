# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1" 

import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from verl.utils.dataset.rl_dataset import RLHFDataset, collate_fn
from torch.utils.data import DataLoader
from vllm import LLM, SamplingParams

# %%
model_path = "/mnt/petrelfs/share_data/zhangshilin/baseline_clp_02_028/actor/global_step_200"

tokenizer = AutoTokenizer.from_pretrained(model_path)
torch.cuda.empty_cache()
base_model = LLM(
    model=model_path,
    tensor_parallel_size=1,
    gpu_memory_utilization=0.85,
    dtype="auto"
)
# Out:
# INFO 08-20 23:58:26 config.py:1450] Downcasting torch.float32 to torch.float16.
# INFO 08-20 23:58:26 llm_engine.py:174] Initializing an LLM engine (v0.5.4) with config: model='/mnt/petrelfs/share_data/zhangshilin/baseline_clp_02_028/actor/global_step_200', speculative_config=None, tokenizer='/mnt/petrelfs/share_data/zhangshilin/baseline_clp_02_028/actor/global_step_200', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, rope_scaling=None, rope_theta=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=16384, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto, quantization_param_path=None, device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='outlines'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None), seed=0, served_model_name=/mnt/petrelfs/share_data/zhangshilin/baseline_clp_02_028/actor/global_step_200, use_v2_block_manager=False, enable_prefix_caching=False)
# INFO 08-20 23:58:27 model_runner.py:720] Starting to load model /mnt/petrelfs/share_data/zhangshilin/baseline_clp_02_028/actor/global_step_200...
# Loading safetensors checkpoint shards:   0% Completed | 0/7 [00:00<?, ?it/s]
# INFO 08-20 23:58:33 model_runner.py:732] Loading model weights took 14.2448 GB
# INFO 08-20 23:58:35 gpu_executor.py:102] # GPU blocks: 59353, # CPU blocks: 4681
# INFO 08-20 23:58:37 model_runner.py:1024] Capturing the model for CUDA graphs. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI.
# INFO 08-20 23:58:37 model_runner.py:1028] CUDA graphs can take additional 1~3 GiB memory per GPU. If you are running out of memory, consider decreasing `gpu_memory_utilization` or enforcing eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# INFO 08-20 23:58:52 model_runner.py:1225] Graph capturing finished in 15 secs.

# %%
val_data_path = "dataset/valid.mmlu_pro.parquet"
val_dataset = RLHFDataset(parquet_files=val_data_path,
                            tokenizer=tokenizer,
                            prompt_key='prompt',
                            max_prompt_length=1024,
                            filter_prompts=True,
                            return_raw_chat=False,
                            truncation='error')

val_dataloader = DataLoader(dataset=val_dataset,
                            batch_size=32,
                            shuffle=False,
                            drop_last=False,
                            collate_fn=collate_fn)
n_val_samples = 16
# Out:
# original dataset len: 12032
# filter dataset len: 12005

# %%
pad_token_id = tokenizer.pad_token_id
from typing import List
def _pre_process_inputs(pad_token_id, prompt_token_ids: torch.Tensor) -> List[int]:
    # remove the left padding in the prompt token_id
    # pad_token_id = self.llm_engine.tokenizer.pad_token_id if self.llm_engine.tokenizer.pad_token_id is not None else self.llm_engine.tokenizer.eos_token_id
    non_pad_index = torch.nonzero(prompt_token_ids != pad_token_id, as_tuple=False)[0][0]
    token_ids = prompt_token_ids[non_pad_index:].tolist()
    return token_ids

# %%
from deepscaler.globals import THOUGHT_DELIMITER_START, THOUGHT_DELIMITER_END, OAI_RM_MODEL
from deepscaler.rewards import RewardConfig, RewardFn, RewardInput, RewardOutput, RewardType
from deepscaler.rewards.math_reward import RewardMathFn
from verl.div_src.reward_fn import RewardManager
reward_fn = RewardMathFn(RewardConfig)
input = RewardInput(problem="", problem_type=RewardType.MATH, model_response="<think> I am omniscient. </think> The answer is \\boxed{24 + 14*x + (-13)*x^2 - 2*x^3 + x^4}.", ground_truth={"answer": "$x^{4}-2 x^{3}-13 x^{2}+14 x+24$"})
output = reward_fn(input)
print(output.reward)
# THOUGHT_DELIMITER_START + output[0].outputs[0].text
# reward_fn = RewardManager(tokenizer=tokenizer, num_examine=0)
# Out:
# 1.0

# %%
from verl import DataProto
reward_tensor_lst = []
data_source_lst = []
sampling_params = SamplingParams(
    temperature=0.6,
    top_p=1.0,
    max_tokens=8192,
)
val_reward_fn = RewardManager(tokenizer=tokenizer, num_examine=1)
for test_data in val_dataloader:
    
    test_batch = DataProto.from_single_dict(test_data)
    test_batch = test_batch.repeat(repeat_times=n_val_samples, interleave=True)
    idx = test_batch.batch['input_ids']
    batch_size = idx.size(0)

    idx_list = [_pre_process_inputs(pad_token_id, idx[i]) for i in range(batch_size)]
    output = base_model.generate(prompts=None,
                                 sampling_params=sampling_params,
                                 prompt_token_ids=idx_list,
                                 use_tqdm=True)
    data_source_lst.append(test_batch.non_tensor_batch.get('data_source', ['unknown'] * batch_size))
    
    def process_item(response, ground_truth):
        reward_input = RewardInput(problem="", problem_type=RewardType.MATH, model_response=THOUGHT_DELIMITER_START+response, ground_truth={"answer": ground_truth})
        return reward_fn(reward_input).is_correct
    # print(test_batch['reward_model'])
    reward_tensor = torch.zeros(batch_size)
    for i in range(batch_size):
        reward_i = process_item(output[i].outputs[0].text, test_batch.non_tensor_batch['reward_model'][i]['ground_truth'])
        reward_tensor[i] = reward_i
    reward_tensor_lst.append(reward_tensor)
# Out:
# Processed prompts:   0%|          | 0/512 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[6], line 18
#      15 batch_size = idx.size(0)
#      17 idx_list = [_pre_process_inputs(pad_token_id, idx[i]) for i in range(batch_size)]
# ---> 18 output = base_model.generate(prompts=None,
#      19                              sampling_params=sampling_params,
#      20                              prompt_token_ids=idx_list,
#      21                              use_tqdm=True)
#      22 data_source_lst.append(test_batch.non_tensor_batch.get('data_source', ['unknown'] * batch_size))
#      24 def process_item(response, ground_truth):
#
# File ~/anaconda3/envs/llm/lib/python3.9/site-packages/vllm/utils.py:895, in deprecate_kwargs.<locals>.wrapper.<locals>.inner(*args, **kwargs)
#     888             msg += f" {additional_message}"
#     890         warnings.warn(
#     891             DeprecationWarning(msg),
#     892             stacklevel=3,  # The inner function takes up one level
#     893         )
# --> 895 return fn(*args, **kwargs)
#
# File ~/anaconda3/envs/llm/lib/python3.9/site-packages/vllm/entrypoints/llm.py:330, in LLM.generate(self, prompts, sampling_params, prompt_token_ids, use_tqdm, lora_request, prompt_adapter_request, guided_options_request)
#     321     sampling_params = SamplingParams()
#     323 self._validate_and_add_requests(
#     324     inputs=inputs,
#     325     params=sampling_params,
#     326     lora_request=lora_request,
#     327     prompt_adapter_request=prompt_adapter_request,
#     328     guided_options=guided_options_request)
# --> 330 outputs = self._run_engine(use_tqdm=use_tqdm)
#     331 return LLMEngine.validate_outputs(outputs, RequestOutput)
#
# File ~/anaconda3/envs/llm/lib/python3.9/site-packages/vllm/entrypoints/llm.py:611, in LLM._run_engine(self, use_tqdm)
#     609 total_out_toks = 0
#     610 while self.llm_engine.has_unfinished_requests():
# --> 611     step_outputs = self.llm_engine.step()
#     612     for output in step_outputs:
#     613         if output.finished:
#
# File ~/anaconda3/envs/llm/lib/python3.9/site-packages/vllm/engine/llm_engine.py:919, in LLMEngine.step(self)
#     909     finished_requests_ids = self.scheduler[
#     910         0].get_and_reset_finished_requests_ids()
#     911     execute_model_req = ExecuteModelRequest(
#     912         seq_group_metadata_list=seq_group_metadata_list,
#     913         blocks_to_swap_in=scheduler_outputs.blocks_to_swap_in,
#    (...)
#     917         running_queue_size=scheduler_outputs.running_queue_size,
#     918         finished_requests_ids=finished_requests_ids)
# --> 919     output = self.model_executor.execute_model(
#     920         execute_model_req=execute_model_req)
#     921 else:
#     922     output = []
#
# File ~/anaconda3/envs/llm/lib/python3.9/site-packages/vllm/executor/gpu_executor.py:110, in GPUExecutor.execute_model(self, execute_model_req)
#     107 def execute_model(
#     108     self, execute_model_req: ExecuteModelRequest
#     109 ) -> Optional[List[Union[SamplerOutput, PoolerOutput]]]:
# --> 110     output = self.driver_worker.execute_model(execute_model_req)
#     111     return output
#
# File ~/anaconda3/envs/llm/lib/python3.9/site-packages/vllm/worker/worker_base.py:273, in LocalOrDistributedWorkerBase.execute_model(self, execute_model_req)
#     268 if not get_pp_group().is_first_rank:
#     269     intermediate_tensors = IntermediateTensors(
#     270         get_pp_group().recv_tensor_dict(
#     271             all_gather_group=get_tp_group()))
# --> 273 output = self.model_runner.execute_model(
#     274     model_input, self.kv_cache[worker_input.virtual_engine]
#     275     if self.kv_cache is not None else None, intermediate_tensors,
#     276     num_steps)
#     278 if not get_pp_group().is_last_rank:
#     279     # output is IntermediateTensors
#     280     get_pp_group().send_tensor_dict(output.tensors,
#     281                                     all_gather_group=get_tp_group())
#
# File ~/anaconda3/envs/llm/lib/python3.9/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/anaconda3/envs/llm/lib/python3.9/site-packages/vllm/worker/model_runner.py:1363, in ModelRunner.execute_model(self, model_input, kv_caches, intermediate_tensors, num_steps)
#    1358 multi_modal_kwargs = model_input.multi_modal_kwargs or {}
#    1359 seqlen_agnostic_kwargs = {
#    1360     "finished_requests_ids": model_input.finished_requests_ids,
#    1361     "request_ids_to_seq_ids": model_input.request_ids_to_seq_ids,
#    1362 } if self.has_seqlen_agnostic else {}
# -> 1363 hidden_or_intermediate_states = model_executable(
#    1364     input_ids=model_input.input_tokens,
#    1365     positions=model_input.input_positions,
#    1366     kv_caches=kv_caches,
#    1367     attn_metadata=model_input.attn_metadata,
#    1368     intermediate_tensors=intermediate_tensors,
#    1369     **MultiModalInputs.as_kwargs(multi_modal_kwargs,
#    1370                                  device=self.device),
#    1371     **seqlen_agnostic_kwargs)
#    1373 # Compute the logits in the last pipeline stage.
#    1374 if not get_pp_group().is_last_rank:
#
# File ~/anaconda3/envs/llm/lib/python3.9/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/llm/lib/python3.9/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/anaconda3/envs/llm/lib/python3.9/site-packages/vllm/model_executor/models/qwen2.py:360, in Qwen2ForCausalLM.forward(self, input_ids, positions, kv_caches, attn_metadata, intermediate_tensors)
#     352 def forward(
#     353     self,
#     354     input_ids: torch.Tensor,
#    (...)
#     358     intermediate_tensors: Optional[IntermediateTensors] = None,
#     359 ) -> torch.Tensor:
# --> 360     hidden_states = self.model(input_ids, positions, kv_caches,
#     361                                attn_metadata, intermediate_tensors)
#     362     return hidden_states
#
# File ~/anaconda3/envs/llm/lib/python3.9/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/llm/lib/python3.9/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/anaconda3/envs/llm/lib/python3.9/site-packages/vllm/model_executor/models/qwen2.py:276, in Qwen2Model.forward(self, input_ids, positions, kv_caches, attn_metadata, intermediate_tensors, inputs_embeds)
#     274 for i in range(self.start_layer, self.end_layer):
#     275     layer = self.layers[i]
# --> 276     hidden_states, residual = layer(
#     277         positions,
#     278         hidden_states,
#     279         kv_caches[i - self.start_layer],
#     280         attn_metadata,
#     281         residual,
#     282     )
#     283 if not get_pp_group().is_last_rank:
#     284     return IntermediateTensors({
#     285         "hidden_states": hidden_states,
#     286         "residual": residual
#     287     })
#
# File ~/anaconda3/envs/llm/lib/python3.9/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/llm/lib/python3.9/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/anaconda3/envs/llm/lib/python3.9/site-packages/vllm/model_executor/models/qwen2.py:220, in Qwen2DecoderLayer.forward(self, positions, hidden_states, kv_cache, attn_metadata, residual)
#     217 # Fully Connected
#     218 hidden_states, residual = self.post_attention_layernorm(
#     219     hidden_states, residual)
# --> 220 hidden_states = self.mlp(hidden_states)
#     221 return hidden_states, residual
#
# File ~/anaconda3/envs/llm/lib/python3.9/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/llm/lib/python3.9/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/anaconda3/envs/llm/lib/python3.9/site-packages/vllm/model_executor/models/qwen2.py:81, in Qwen2MLP.forward(self, x)
#      79 gate_up, _ = self.gate_up_proj(x)
#      80 x = self.act_fn(gate_up)
# ---> 81 x, _ = self.down_proj(x)
#      82 return x
#
# File ~/anaconda3/envs/llm/lib/python3.9/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/llm/lib/python3.9/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/anaconda3/envs/llm/lib/python3.9/site-packages/vllm/model_executor/layers/linear.py:787, in RowParallelLinear.forward(self, input_)
#     784 # Only fuse bias add into GEMM for rank 0 (this ensures that
#     785 # bias will not get added more than once in TP>1 case)
#     786 bias_ = None if (self.tp_rank > 0 or self.skip_bias_add) else self.bias
# --> 787 output_parallel = self.quant_method.apply(self,
#     788                                           input_parallel,
#     789                                           bias=bias_)
#     790 if self.reduce_results and self.tp_size > 1:
#     791     output = tensor_model_parallel_all_reduce(output_parallel)
#
# File ~/anaconda3/envs/llm/lib/python3.9/site-packages/vllm/model_executor/layers/linear.py:122, in UnquantizedLinearMethod.apply(self, layer, x, bias)
#     117 def apply(self,
#     118           layer: torch.nn.Module,
#     119           x: torch.Tensor,
#     120           bias: Optional[torch.Tensor] = None) -> torch.Tensor:
# --> 122     return F.linear(x, layer.weight, bias)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 112.00 MiB. GPU 0 has a total capacity of 79.33 GiB of which 34.44 MiB is free. Process 20195 has 10.95 GiB memory in use. Including non-PyTorch memory, this process has 68.32 GiB memory in use. Of the allocated memory 66.98 GiB is allocated by PyTorch, with 42.53 MiB allocated in private pools (e.g., CUDA Graphs), and 103.52 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
# print(len(reward_tensor_lst[0]))
import numpy as np
reward_tensors = torch.cat(reward_tensor_lst, dim=0).reshape(-1, n_val_samples).any(dim=-1)
data_sources = np.concatenate(data_source_lst, axis=0).reshape(-1, n_val_samples)[:,0]
data_source_reward = {}
for i in range(reward_tensors.shape[0]):
    data_source = data_sources[i]
    if data_source not in data_source_reward:
        data_source_reward[data_source] = []
    data_source_reward[data_source].append(reward_tensors[i])
metric_dict = {}
average_score = []
for data_source, rewards in data_source_reward.items():
    metric_dict[f'val/test_score/{data_source}'] = np.mean(rewards)
    average_score.append(metric_dict[f'val/test_score/{data_source}'])
metric_dict[f'val/test_score/average'] = np.mean(average_score)
print(metric_dict)

# %%
# for i in range(batch_size):
#     print(f"**************{i}**************")
#     print("ground_truth:", test_batch.non_tensor_batch['reward_model'][i]['ground_truth'])
#     print(output[i].outputs[0].text)
#     print("_______________________________")
