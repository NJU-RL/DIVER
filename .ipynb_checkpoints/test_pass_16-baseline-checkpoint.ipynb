# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "4" 

import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from verl.utils.dataset.rl_dataset import RLHFDataset, collate_fn
from torch.utils.data import DataLoader
from vllm import LLM, SamplingParams

# %%
model_path = "/mnt/petrelfs/share_data/zhangshilin/baseline_clp_02_028/actor/global_step_200"

tokenizer = AutoTokenizer.from_pretrained(model_path)
torch.cuda.empty_cache()
base_model = LLM(
    model=model_path,
    tensor_parallel_size=1,
    gpu_memory_utilization=0.85,
    dtype="auto"
)
# Out:
# INFO 08-18 22:12:46 config.py:1450] Downcasting torch.float32 to torch.float16.
# INFO 08-18 22:12:46 llm_engine.py:174] Initializing an LLM engine (v0.5.4) with config: model='/mnt/petrelfs/share_data/zhangshilin/baseline_clp_02_028/actor/global_step_200', speculative_config=None, tokenizer='/mnt/petrelfs/share_data/zhangshilin/baseline_clp_02_028/actor/global_step_200', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, rope_scaling=None, rope_theta=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=16384, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto, quantization_param_path=None, device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='outlines'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None), seed=0, served_model_name=/mnt/petrelfs/share_data/zhangshilin/baseline_clp_02_028/actor/global_step_200, use_v2_block_manager=False, enable_prefix_caching=False)
# INFO 08-18 22:12:46 model_runner.py:720] Starting to load model /mnt/petrelfs/share_data/zhangshilin/baseline_clp_02_028/actor/global_step_200...
# Loading safetensors checkpoint shards:   0% Completed | 0/7 [00:00<?, ?it/s]
# INFO 08-18 22:12:56 model_runner.py:732] Loading model weights took 14.2448 GB
# INFO 08-18 22:12:57 gpu_executor.py:102] # GPU blocks: 59353, # CPU blocks: 4681
# INFO 08-18 22:13:00 model_runner.py:1024] Capturing the model for CUDA graphs. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI.
# INFO 08-18 22:13:00 model_runner.py:1028] CUDA graphs can take additional 1~3 GiB memory per GPU. If you are running out of memory, consider decreasing `gpu_memory_utilization` or enforcing eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# INFO 08-18 22:13:14 model_runner.py:1225] Graph capturing finished in 14 secs.

# %%
val_data_path = "dataset/eval.passn.parquet"
val_dataset = RLHFDataset(parquet_files=val_data_path,
                            tokenizer=tokenizer,
                            prompt_key='prompt',
                            max_prompt_length=1024,
                            filter_prompts=True,
                            return_raw_chat=False,
                            truncation='error')

val_dataloader = DataLoader(dataset=val_dataset,
                            batch_size=8,
                            shuffle=False,
                            drop_last=False,
                            collate_fn=collate_fn)
n_val_samples = 16
# Out:
# original dataset len: 1590
# filter dataset len: 1588

# %%
pad_token_id = tokenizer.pad_token_id
from typing import List
def _pre_process_inputs(pad_token_id, prompt_token_ids: torch.Tensor) -> List[int]:
    # remove the left padding in the prompt token_id
    # pad_token_id = self.llm_engine.tokenizer.pad_token_id if self.llm_engine.tokenizer.pad_token_id is not None else self.llm_engine.tokenizer.eos_token_id
    non_pad_index = torch.nonzero(prompt_token_ids != pad_token_id, as_tuple=False)[0][0]
    token_ids = prompt_token_ids[non_pad_index:].tolist()
    return token_ids

# %%
from deepscaler.globals import THOUGHT_DELIMITER_START, THOUGHT_DELIMITER_END, OAI_RM_MODEL
from deepscaler.rewards import RewardConfig, RewardFn, RewardInput, RewardOutput, RewardType
from deepscaler.rewards.math_reward import RewardMathFn
from verl.div_src.reward_fn import RewardManager
reward_fn = RewardMathFn(RewardConfig)
input = RewardInput(problem="", problem_type=RewardType.MATH, model_response="<think> I am omniscient. </think> The answer is \\boxed{24 + 14*x + (-13)*x^2 - 2*x^3 + x^4}.", ground_truth={"answer": "$x^{4}-2 x^{3}-13 x^{2}+14 x+24$"})
output = reward_fn(input)
print(output.reward)
# THOUGHT_DELIMITER_START + output[0].outputs[0].text
# reward_fn = RewardManager(tokenizer=tokenizer, num_examine=0)
# Out:
# 1.0

# %%
from verl import DataProto
reward_tensor_lst = []
data_source_lst = []
sampling_params = SamplingParams(
    temperature=0.6,
    top_p=1.0,
    max_tokens=8192,
)
val_reward_fn = RewardManager(tokenizer=tokenizer, num_examine=1)
for test_data in val_dataloader:
    
    test_batch = DataProto.from_single_dict(test_data)
    test_batch = test_batch.repeat(repeat_times=n_val_samples, interleave=True)
    idx = test_batch.batch['input_ids']
    batch_size = idx.size(0)

    idx_list = [_pre_process_inputs(pad_token_id, idx[i]) for i in range(batch_size)]
    output = base_model.generate(prompts=None,
                                 sampling_params=sampling_params,
                                 prompt_token_ids=idx_list,
                                 use_tqdm=True)
    data_source_lst.append(test_batch.non_tensor_batch.get('data_source', ['unknown'] * batch_size))
    
    def process_item(response, ground_truth):
        reward_input = RewardInput(problem="", problem_type=RewardType.MATH, model_response=THOUGHT_DELIMITER_START+response, ground_truth={"answer": ground_truth})
        return reward_fn(reward_input).is_correct
    # print(test_batch['reward_model'])
    reward_tensor = torch.zeros(batch_size)
    for i in range(batch_size):
        reward_i = process_item(output[i].outputs[0].text, test_batch.non_tensor_batch['reward_model'][i]['ground_truth'])
        reward_tensor[i] = reward_i
    reward_tensor_lst.append(reward_tensor)
# Out:
# Processed prompts: 100%|██████████| 128/128 [01:53<00:00,  1.13it/s, est. speed input: 270.93 toks/s, output: 847.03 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:42<00:00,  3.04it/s, est. speed input: 776.82 toks/s, output: 2043.89 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:54<00:00,  1.12it/s, est. speed input: 262.42 toks/s, output: 975.01 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:30<00:00,  4.14it/s, est. speed input: 880.06 toks/s, output: 2564.23 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:25<00:00,  5.02it/s, est. speed input: 971.53 toks/s, output: 2855.11 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:53<00:00,  1.13it/s, est. speed input: 243.76 toks/s, output: 921.17 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:32<00:00,  3.97it/s, est. speed input: 759.34 toks/s, output: 2099.35 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:57<00:00,  2.24it/s, est. speed input: 476.77 toks/s, output: 1807.54 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:36<00:00,  3.47it/s, est. speed input: 687.02 toks/s, output: 2007.66 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:20<00:00,  6.13it/s, est. speed input: 1196.03 toks/s, output: 2723.90 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:32<00:00,  3.94it/s, est. speed input: 799.50 toks/s, output: 2695.94 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:32<00:00,  3.93it/s, est. speed input: 958.89 toks/s, output: 2696.24 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:21<00:00,  1.57it/s, est. speed input: 397.49 toks/s, output: 1883.17 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:11<00:00,  1.03s/it, est. speed input: 256.70 toks/s, output: 1225.34 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:34<00:00,  3.74it/s, est. speed input: 777.97 toks/s, output: 2416.21 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:56<00:00,  1.09it/s, est. speed input: 244.15 toks/s, output: 924.22 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:31<00:00,  4.03it/s, est. speed input: 840.30 toks/s, output: 2533.61 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:50<00:00,  2.52it/s, est. speed input: 543.29 toks/s, output: 2028.25 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:56<00:00,  2.26it/s, est. speed input: 537.84 toks/s, output: 2022.22 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:58<00:00,  1.08it/s, est. speed input: 258.29 toks/s, output: 931.68 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:39<00:00,  3.28it/s, est. speed input: 727.09 toks/s, output: 2101.14 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:43<00:00,  2.92it/s, est. speed input: 798.88 toks/s, output: 2292.72 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:30<00:00,  4.25it/s, est. speed input: 964.99 toks/s, output: 2611.48 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:57<00:00,  1.09it/s, est. speed input: 290.15 toks/s, output: 917.44 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:36<00:00,  3.49it/s, est. speed input: 683.57 toks/s, output: 2192.27 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:54<00:00,  1.12it/s, est. speed input: 257.16 toks/s, output: 919.07 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:34<00:00,  3.76it/s, est. speed input: 841.09 toks/s, output: 2231.16 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:31<00:00,  4.06it/s, est. speed input: 1181.81 toks/s, output: 2431.63 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:39<00:00,  3.24it/s, est. speed input: 716.69 toks/s, output: 2533.02 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:00<00:00,  2.13it/s, est. speed input: 469.91 toks/s, output: 2139.13 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:32<00:00,  3.99it/s, est. speed input: 921.25 toks/s, output: 2647.79 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:08<00:00,  1.87it/s, est. speed input: 395.14 toks/s, output: 1462.75 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:21<00:00,  6.09it/s, est. speed input: 1159.71 toks/s, output: 2748.08 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:30<00:00,  4.26it/s, est. speed input: 1012.90 toks/s, output: 2286.55 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:27<00:00,  4.69it/s, est. speed input: 995.18 toks/s, output: 2636.74 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:13<00:00,  1.05s/it, est. speed input: 255.98 toks/s, output: 1188.78 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:54<00:00,  2.36it/s, est. speed input: 546.56 toks/s, output: 2464.30 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:58<00:00,  1.08it/s, est. speed input: 360.80 toks/s, output: 997.21 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:44<00:00,  2.88it/s, est. speed input: 583.20 toks/s, output: 2467.62 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:32<00:00,  3.97it/s, est. speed input: 799.23 toks/s, output: 2275.36 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:59<00:00,  1.08it/s, est. speed input: 261.44 toks/s, output: 987.64 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:44<00:00,  2.89it/s, est. speed input: 590.87 toks/s, output: 2635.30 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:56<00:00,  2.27it/s, est. speed input: 440.87 toks/s, output: 1557.67 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:34<00:00,  3.75it/s, est. speed input: 736.25 toks/s, output: 2134.92 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:48<00:00,  2.66it/s, est. speed input: 602.82 toks/s, output: 2457.12 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:31<00:00,  4.04it/s, est. speed input: 921.60 toks/s, output: 2530.62 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:56<00:00,  2.25it/s, est. speed input: 539.60 toks/s, output: 1499.95 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:38<00:00,  3.31it/s, est. speed input: 793.32 toks/s, output: 2754.85 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:30<00:00,  4.23it/s, est. speed input: 912.12 toks/s, output: 2451.32 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:57<00:00,  1.09it/s, est. speed input: 291.61 toks/s, output: 947.78 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:35<00:00,  1.22s/it, est. speed input: 161.38 toks/s, output: 1107.48 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:03<00:00,  1.03it/s, est. speed input: 212.55 toks/s, output: 945.71 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:11<00:00,  1.80it/s, est. speed input: 399.33 toks/s, output: 1958.10 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:07<00:00,  1.00it/s, est. speed input: 214.86 toks/s, output: 1080.49 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:09<00:00,  1.01s/it, est. speed input: 197.05 toks/s, output: 1080.42 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:49<00:00,  2.58it/s, est. speed input: 608.92 toks/s, output: 1951.91 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:33<00:00,  3.84it/s, est. speed input: 807.48 toks/s, output: 2485.13 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:39<00:00,  3.23it/s, est. speed input: 759.17 toks/s, output: 2116.95 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:39<00:00,  3.27it/s, est. speed input: 705.39 toks/s, output: 2200.07 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:01<00:00,  1.05it/s, est. speed input: 255.74 toks/s, output: 988.08 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:48<00:00,  2.62it/s, est. speed input: 603.40 toks/s, output: 2448.23 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:48<00:00,  2.65it/s, est. speed input: 613.10 toks/s, output: 2278.48 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:51<00:00,  2.49it/s, est. speed input: 583.00 toks/s, output: 2445.09 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:08<00:00,  1.87it/s, est. speed input: 493.97 toks/s, output: 2332.92 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:20<00:00,  1.10s/it, est. speed input: 240.06 toks/s, output: 1366.16 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:13<00:00,  1.75it/s, est. speed input: 445.72 toks/s, output: 2295.27 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:27<00:00,  1.46it/s, est. speed input: 376.96 toks/s, output: 2008.24 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:18<00:00,  1.08s/it, est. speed input: 281.55 toks/s, output: 1300.45 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:11<00:00,  1.03s/it, est. speed input: 246.63 toks/s, output: 1464.88 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:14<00:00,  1.71it/s, est. speed input: 487.24 toks/s, output: 2273.89 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:08<00:00,  1.86it/s, est. speed input: 549.97 toks/s, output: 2501.45 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:06<00:00,  1.94it/s, est. speed input: 542.57 toks/s, output: 2627.57 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:02<00:00,  2.04it/s, est. speed input: 598.00 toks/s, output: 2474.88 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:04<00:00,  1.99it/s, est. speed input: 575.26 toks/s, output: 2651.69 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:02<00:00,  1.05it/s, est. speed input: 273.54 toks/s, output: 1082.67 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:05<00:00,  1.95it/s, est. speed input: 568.25 toks/s, output: 2354.53 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:15<00:00,  1.06s/it, est. speed input: 246.13 toks/s, output: 1330.16 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:16<00:00,  1.07s/it, est. speed input: 254.90 toks/s, output: 1342.09 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:46<00:00,  2.76it/s, est. speed input: 609.30 toks/s, output: 2080.01 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:59<00:00,  2.16it/s, est. speed input: 495.18 toks/s, output: 2015.12 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:08<00:00,  1.00s/it, est. speed input: 283.20 toks/s, output: 1076.28 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:42<00:00,  3.01it/s, est. speed input: 693.07 toks/s, output: 1995.56 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:08<00:00,  1.87it/s, est. speed input: 488.91 toks/s, output: 2383.61 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:23<00:00,  1.12s/it, est. speed input: 232.50 toks/s, output: 1371.57 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:55<00:00,  1.11it/s, est. speed input: 280.03 toks/s, output: 879.71 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:31<00:00,  1.40it/s, est. speed input: 379.66 toks/s, output: 2012.18 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:04<00:00,  1.03it/s, est. speed input: 255.83 toks/s, output: 1138.72 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:01<00:00,  1.05it/s, est. speed input: 269.61 toks/s, output: 982.00 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:04<00:00,  1.99it/s, est. speed input: 459.74 toks/s, output: 2350.11 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:46<00:00,  2.76it/s, est. speed input: 597.68 toks/s, output: 2229.36 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:42<00:00,  1.25it/s, est. speed input: 349.93 toks/s, output: 1399.46 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:51<00:00,  2.48it/s, est. speed input: 692.00 toks/s, output: 2469.47 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:32<00:00,  3.88it/s, est. speed input: 858.22 toks/s, output: 2940.14 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:14<00:00,  1.05s/it, est. speed input: 255.89 toks/s, output: 1308.27 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:54<00:00,  2.35it/s, est. speed input: 566.53 toks/s, output: 2092.55 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:01<00:00,  2.09it/s, est. speed input: 535.84 toks/s, output: 2371.95 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:50<00:00,  2.54it/s, est. speed input: 608.83 toks/s, output: 2642.95 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:14<00:00,  1.05s/it, est. speed input: 234.70 toks/s, output: 1332.29 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:40<00:00,  3.12it/s, est. speed input: 672.24 toks/s, output: 2647.49 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:18<00:00,  1.63it/s, est. speed input: 376.50 toks/s, output: 1669.86 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:12<00:00,  1.04s/it, est. speed input: 229.84 toks/s, output: 1240.60 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:13<00:00,  1.04s/it, est. speed input: 243.05 toks/s, output: 1169.00 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:00<00:00,  1.06it/s, est. speed input: 247.57 toks/s, output: 995.79 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:12<00:00,  1.03s/it, est. speed input: 216.18 toks/s, output: 1219.77 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:00<00:00,  2.10it/s, est. speed input: 691.34 toks/s, output: 2237.68 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:15<00:00,  1.69it/s, est. speed input: 377.69 toks/s, output: 2465.10 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:52<00:00,  1.13it/s, est. speed input: 241.43 toks/s, output: 876.10 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:44<00:00,  1.22it/s, est. speed input: 251.66 toks/s, output: 956.95 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:46<00:00,  1.20it/s, est. speed input: 265.77 toks/s, output: 1669.57 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:58<00:00,  2.21it/s, est. speed input: 548.93 toks/s, output: 2287.96 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:06<00:00,  1.01it/s, est. speed input: 506.47 toks/s, output: 1058.85 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:23<00:00,  1.12s/it, est. speed input: 219.12 toks/s, output: 1407.77 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:06<00:00,  1.01it/s, est. speed input: 246.45 toks/s, output: 1142.18 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:59<00:00,  1.07it/s, est. speed input: 232.90 toks/s, output: 1015.22 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:13<00:00,  1.04s/it, est. speed input: 218.66 toks/s, output: 1241.12 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:19<00:00,  1.09s/it, est. speed input: 234.04 toks/s, output: 1238.06 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:24<00:00,  1.13s/it, est. speed input: 197.54 toks/s, output: 1399.68 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:19<00:00,  1.09s/it, est. speed input: 227.01 toks/s, output: 1272.23 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:51<00:00,  1.15it/s, est. speed input: 233.48 toks/s, output: 792.72 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:18<00:00,  1.08s/it, est. speed input: 207.45 toks/s, output: 1227.48 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:08<00:00,  1.00s/it, est. speed input: 236.92 toks/s, output: 1203.14 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:09<00:00,  1.01s/it, est. speed input: 220.07 toks/s, output: 1241.62 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:13<00:00,  1.75it/s, est. speed input: 390.05 toks/s, output: 2211.34 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:54<00:00,  1.12it/s, est. speed input: 256.82 toks/s, output: 887.29 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:23<00:00,  1.12s/it, est. speed input: 205.69 toks/s, output: 1257.86 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:07<00:00,  1.00it/s, est. speed input: 206.72 toks/s, output: 1195.03 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:19<00:00,  1.09s/it, est. speed input: 389.02 toks/s, output: 1234.16 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:32<00:00,  1.19s/it, est. speed input: 205.60 toks/s, output: 1344.93 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:41<00:00,  3.08it/s, est. speed input: 686.40 toks/s, output: 2097.19 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:13<00:00,  1.04s/it, est. speed input: 207.90 toks/s, output: 1258.75 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:31<00:00,  1.40it/s, est. speed input: 362.73 toks/s, output: 2286.84 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:10<00:00,  1.02s/it, est. speed input: 231.17 toks/s, output: 1154.16 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:05<00:00,  1.94it/s, est. speed input: 470.31 toks/s, output: 2225.41 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:13<00:00,  1.74it/s, est. speed input: 399.75 toks/s, output: 1931.00 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:22<00:00,  1.11s/it, est. speed input: 211.99 toks/s, output: 1287.93 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:20<00:00,  1.10s/it, est. speed input: 207.11 toks/s, output: 1325.78 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:06<00:00,  1.93it/s, est. speed input: 599.67 toks/s, output: 2029.59 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:55<00:00,  2.32it/s, est. speed input: 901.14 toks/s, output: 2562.50 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:21<00:00,  1.11s/it, est. speed input: 197.58 toks/s, output: 1370.05 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:22<00:00,  1.56it/s, est. speed input: 350.79 toks/s, output: 1939.75 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:35<00:00,  3.60it/s, est. speed input: 809.61 toks/s, output: 2568.47 toks/s]
# Processed prompts:  95%|█████████▌| 122/128 [00:52<00:07,  1.24s/it, est. speed input: 528.72 toks/s, output: 2126.25 toks/s]

# %%
# print(len(reward_tensor_lst[0]))
import numpy as np
reward_tensors = torch.cat(reward_tensor_lst, dim=0).reshape(-1, n_val_samples).any(dim=-1)
data_sources = np.concatenate(data_source_lst, axis=0).reshape(-1, n_val_samples)[:,0]
data_source_reward = {}
for i in range(reward_tensors.shape[0]):
    data_source = data_sources[i]
    if data_source not in data_source_reward:
        data_source_reward[data_source] = []
    data_source_reward[data_source].append(reward_tensors[i])
metric_dict = {}
average_score = []
for data_source, rewards in data_source_reward.items():
    metric_dict[f'val/test_score/{data_source}'] = np.mean(rewards)
    average_score.append(metric_dict[f'val/test_score/{data_source}'])
metric_dict[f'val/test_score/average'] = np.mean(average_score)
print(metric_dict)

# %%
# for i in range(batch_size):
#     print(f"**************{i}**************")
#     print("ground_truth:", test_batch.non_tensor_batch['reward_model'][i]['ground_truth'])
#     print(output[i].outputs[0].text)
#     print("_______________________________")
