# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "7" 

import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from verl.utils.dataset.rl_dataset import RLHFDataset, collate_fn
from torch.utils.data import DataLoader
from vllm import LLM, SamplingParams

# %%
model_path = "/mnt/petrelfs/huzican/R1/rlvr_div/checkpoints/div/pos_rs_0.1-neg_rs_0.01-equ+belu+rule-piecewise_error/actor/global_step_200"

tokenizer = AutoTokenizer.from_pretrained(model_path)
torch.cuda.empty_cache()
base_model = LLM(
    model=model_path,
    tensor_parallel_size=1,
    gpu_memory_utilization=0.85,
    dtype="auto"
)
# Out:
# INFO 08-18 21:40:39 config.py:1450] Downcasting torch.float32 to torch.float16.
# INFO 08-18 21:40:39 llm_engine.py:174] Initializing an LLM engine (v0.5.4) with config: model='/mnt/petrelfs/huzican/R1/rlvr_div/checkpoints/div/pos_rs_0.1-neg_rs_0.01-equ+belu+rule-piecewise_error/actor/global_step_200', speculative_config=None, tokenizer='/mnt/petrelfs/huzican/R1/rlvr_div/checkpoints/div/pos_rs_0.1-neg_rs_0.01-equ+belu+rule-piecewise_error/actor/global_step_200', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, rope_scaling=None, rope_theta=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=16384, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto, quantization_param_path=None, device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='outlines'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None), seed=0, served_model_name=/mnt/petrelfs/huzican/R1/rlvr_div/checkpoints/div/pos_rs_0.1-neg_rs_0.01-equ+belu+rule-piecewise_error/actor/global_step_200, use_v2_block_manager=False, enable_prefix_caching=False)
# INFO 08-18 21:40:39 model_runner.py:720] Starting to load model /mnt/petrelfs/huzican/R1/rlvr_div/checkpoints/div/pos_rs_0.1-neg_rs_0.01-equ+belu+rule-piecewise_error/actor/global_step_200...
# Loading safetensors checkpoint shards:   0% Completed | 0/7 [00:00<?, ?it/s]
# INFO 08-18 21:40:45 model_runner.py:732] Loading model weights took 14.2448 GB
# INFO 08-18 21:40:47 gpu_executor.py:102] # GPU blocks: 59353, # CPU blocks: 4681
# INFO 08-18 21:40:49 model_runner.py:1024] Capturing the model for CUDA graphs. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI.
# INFO 08-18 21:40:49 model_runner.py:1028] CUDA graphs can take additional 1~3 GiB memory per GPU. If you are running out of memory, consider decreasing `gpu_memory_utilization` or enforcing eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# INFO 08-18 21:41:01 model_runner.py:1225] Graph capturing finished in 12 secs.

# %%
val_data_path = "dataset/eval.passn.parquet"
val_dataset = RLHFDataset(parquet_files=val_data_path,
                            tokenizer=tokenizer,
                            prompt_key='prompt',
                            max_prompt_length=1024,
                            filter_prompts=True,
                            return_raw_chat=False,
                            truncation='error')

val_dataloader = DataLoader(dataset=val_dataset,
                            batch_size=8,
                            shuffle=False,
                            drop_last=False,
                            collate_fn=collate_fn)
n_val_samples = 16
# Out:
# original dataset len: 1590
# filter dataset len: 1588

# %%
pad_token_id = tokenizer.pad_token_id
from typing import List
def _pre_process_inputs(pad_token_id, prompt_token_ids: torch.Tensor) -> List[int]:
    # remove the left padding in the prompt token_id
    # pad_token_id = self.llm_engine.tokenizer.pad_token_id if self.llm_engine.tokenizer.pad_token_id is not None else self.llm_engine.tokenizer.eos_token_id
    non_pad_index = torch.nonzero(prompt_token_ids != pad_token_id, as_tuple=False)[0][0]
    token_ids = prompt_token_ids[non_pad_index:].tolist()
    return token_ids

# %%
from deepscaler.globals import THOUGHT_DELIMITER_START, THOUGHT_DELIMITER_END, OAI_RM_MODEL
from deepscaler.rewards import RewardConfig, RewardFn, RewardInput, RewardOutput, RewardType
from deepscaler.rewards.math_reward import RewardMathFn
from verl.div_src.reward_fn import RewardManager
reward_fn = RewardMathFn(RewardConfig)
input = RewardInput(problem="", problem_type=RewardType.MATH, model_response="<think> I am omniscient. </think> The answer is \\boxed{24 + 14*x + (-13)*x^2 - 2*x^3 + x^4}.", ground_truth={"answer": "$x^{4}-2 x^{3}-13 x^{2}+14 x+24$"})
output = reward_fn(input)
print(output.reward)
# THOUGHT_DELIMITER_START + output[0].outputs[0].text
# reward_fn = RewardManager(tokenizer=tokenizer, num_examine=0)
# Out:
# 1.0

# %%
from verl import DataProto
reward_tensor_lst = []
data_source_lst = []
sampling_params = SamplingParams(
    temperature=0.6,
    top_p=1.0,
    max_tokens=8192,
)
val_reward_fn = RewardManager(tokenizer=tokenizer, num_examine=1)
for test_data in val_dataloader:
    
    test_batch = DataProto.from_single_dict(test_data)
    test_batch = test_batch.repeat(repeat_times=n_val_samples, interleave=True)
    idx = test_batch.batch['input_ids']
    batch_size = idx.size(0)

    idx_list = [_pre_process_inputs(pad_token_id, idx[i]) for i in range(batch_size)]
    output = base_model.generate(prompts=None,
                                 sampling_params=sampling_params,
                                 prompt_token_ids=idx_list,
                                 use_tqdm=True)
    data_source_lst.append(test_batch.non_tensor_batch.get('data_source', ['unknown'] * batch_size))
    
    def process_item(response, ground_truth):
        reward_input = RewardInput(problem="", problem_type=RewardType.MATH, model_response=THOUGHT_DELIMITER_START+response, ground_truth={"answer": ground_truth})
        return reward_fn(reward_input).is_correct
    # print(test_batch['reward_model'])
    reward_tensor = torch.zeros(batch_size)
    for i in range(batch_size):
        reward_i = process_item(output[i].outputs[0].text, test_batch.non_tensor_batch['reward_model'][i]['ground_truth'])
        reward_tensor[i] = reward_i
    reward_tensor_lst.append(reward_tensor)
# Out:
# Processed prompts: 100%|██████████| 128/128 [00:31<00:00,  4.05it/s, est. speed input: 974.39 toks/s, output: 3154.09 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:17<00:00,  1.66it/s, est. speed input: 423.46 toks/s, output: 1653.44 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:25<00:00,  1.14s/it, est. speed input: 205.43 toks/s, output: 1390.17 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:01<00:00,  2.08it/s, est. speed input: 443.44 toks/s, output: 1841.57 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:42<00:00,  3.04it/s, est. speed input: 588.32 toks/s, output: 2458.72 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:04<00:00,  1.03it/s, est. speed input: 220.79 toks/s, output: 1165.76 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:36<00:00,  3.50it/s, est. speed input: 670.23 toks/s, output: 2814.95 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:06<00:00,  1.01it/s, est. speed input: 215.27 toks/s, output: 1242.66 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:58<00:00,  1.08it/s, est. speed input: 214.98 toks/s, output: 1092.80 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:31<00:00,  4.06it/s, est. speed input: 792.52 toks/s, output: 2604.85 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:01<00:00,  2.06it/s, est. speed input: 419.45 toks/s, output: 2143.87 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:52<00:00,  2.45it/s, est. speed input: 597.12 toks/s, output: 2304.15 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:29<00:00,  1.17s/it, est. speed input: 215.97 toks/s, output: 1526.36 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:30<00:00,  1.17s/it, est. speed input: 225.49 toks/s, output: 1459.36 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:02<00:00,  2.03it/s, est. speed input: 422.88 toks/s, output: 1784.04 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:15<00:00,  1.69it/s, est. speed input: 377.82 toks/s, output: 1831.63 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:51<00:00,  2.47it/s, est. speed input: 516.42 toks/s, output: 2072.21 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:15<00:00,  1.69it/s, est. speed input: 364.74 toks/s, output: 1782.74 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:05<00:00,  1.02it/s, est. speed input: 242.03 toks/s, output: 1204.84 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:03<00:00,  1.04it/s, est. speed input: 248.66 toks/s, output: 1125.74 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:05<00:00,  1.96it/s, est. speed input: 433.73 toks/s, output: 1790.88 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:06<00:00,  1.01it/s, est. speed input: 275.92 toks/s, output: 1200.91 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:51<00:00,  2.48it/s, est. speed input: 563.12 toks/s, output: 2119.10 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:00<00:00,  2.12it/s, est. speed input: 564.41 toks/s, output: 2323.14 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:58<00:00,  2.18it/s, est. speed input: 427.29 toks/s, output: 2220.20 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:20<00:00,  1.10s/it, est. speed input: 209.64 toks/s, output: 1287.76 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:58<00:00,  1.08it/s, est. speed input: 240.80 toks/s, output: 1015.56 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:37<00:00,  3.42it/s, est. speed input: 994.86 toks/s, output: 2755.78 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:58<00:00,  1.08it/s, est. speed input: 239.51 toks/s, output: 1093.17 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:19<00:00,  1.09s/it, est. speed input: 202.66 toks/s, output: 1300.48 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:59<00:00,  1.07it/s, est. speed input: 247.24 toks/s, output: 1080.22 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:05<00:00,  1.02it/s, est. speed input: 216.36 toks/s, output: 1111.64 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:28<00:00,  4.56it/s, est. speed input: 868.46 toks/s, output: 2661.11 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:04<00:00,  1.03it/s, est. speed input: 243.96 toks/s, output: 988.55 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:55<00:00,  1.11it/s, est. speed input: 235.91 toks/s, output: 878.37 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:48<00:00,  1.32s/it, est. speed input: 203.64 toks/s, output: 1430.14 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:05<00:00,  1.96it/s, est. speed input: 452.85 toks/s, output: 2409.39 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:09<00:00,  1.01s/it, est. speed input: 329.88 toks/s, output: 1234.74 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:12<00:00,  1.76it/s, est. speed input: 355.69 toks/s, output: 2046.51 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:39<00:00,  3.24it/s, est. speed input: 651.12 toks/s, output: 2468.20 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:09<00:00,  1.83it/s, est. speed input: 445.17 toks/s, output: 1906.51 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:15<00:00,  1.69it/s, est. speed input: 345.66 toks/s, output: 1835.97 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:52<00:00,  2.44it/s, est. speed input: 475.21 toks/s, output: 2195.57 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:54<00:00,  2.36it/s, est. speed input: 463.79 toks/s, output: 1997.95 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:19<00:00,  1.09s/it, est. speed input: 208.00 toks/s, output: 1294.42 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:03<00:00,  1.03it/s, est. speed input: 235.85 toks/s, output: 1103.24 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:54<00:00,  2.34it/s, est. speed input: 561.15 toks/s, output: 2172.12 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:58<00:00,  2.20it/s, est. speed input: 527.19 toks/s, output: 2260.70 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:54<00:00,  1.12it/s, est. speed input: 240.66 toks/s, output: 883.35 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:10<00:00,  1.02s/it, est. speed input: 262.67 toks/s, output: 1135.48 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:21<00:00,  1.10s/it, est. speed input: 178.19 toks/s, output: 1213.71 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:11<00:00,  1.79it/s, est. speed input: 368.55 toks/s, output: 1903.80 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:16<00:00,  1.07s/it, est. speed input: 207.13 toks/s, output: 1366.79 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:12<00:00,  1.03s/it, est. speed input: 207.78 toks/s, output: 1163.69 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:16<00:00,  1.06s/it, est. speed input: 187.58 toks/s, output: 1258.49 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:58<00:00,  2.20it/s, est. speed input: 518.66 toks/s, output: 1961.93 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:46<00:00,  2.74it/s, est. speed input: 575.43 toks/s, output: 2309.36 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:44<00:00,  2.90it/s, est. speed input: 681.91 toks/s, output: 2394.91 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:57<00:00,  2.21it/s, est. speed input: 478.28 toks/s, output: 1983.38 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:06<00:00,  1.01it/s, est. speed input: 245.50 toks/s, output: 1183.45 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:14<00:00,  1.05s/it, est. speed input: 219.21 toks/s, output: 1270.41 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:03<00:00,  2.00it/s, est. speed input: 462.39 toks/s, output: 2355.45 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:10<00:00,  1.02s/it, est. speed input: 229.51 toks/s, output: 1262.47 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:39<00:00,  1.25s/it, est. speed input: 212.01 toks/s, output: 1462.52 toks/s]
# Processed prompts: 100%|██████████| 128/128 [03:04<00:00,  1.44s/it, est. speed input: 182.43 toks/s, output: 1532.50 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:42<00:00,  1.27s/it, est. speed input: 201.56 toks/s, output: 1543.88 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:46<00:00,  1.30s/it, est. speed input: 198.42 toks/s, output: 1513.37 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:33<00:00,  1.20s/it, est. speed input: 255.06 toks/s, output: 1562.16 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:45<00:00,  1.29s/it, est. speed input: 197.12 toks/s, output: 1588.95 toks/s]
# Processed prompts: 100%|██████████| 128/128 [03:04<00:00,  1.44s/it, est. speed input: 197.21 toks/s, output: 1486.04 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:35<00:00,  1.35it/s, est. speed input: 397.58 toks/s, output: 2285.19 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:31<00:00,  1.18s/it, est. speed input: 236.89 toks/s, output: 1483.07 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:41<00:00,  1.26it/s, est. speed input: 369.72 toks/s, output: 1928.02 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:48<00:00,  1.32s/it, est. speed input: 219.57 toks/s, output: 1519.61 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:16<00:00,  1.07s/it, est. speed input: 244.55 toks/s, output: 1301.99 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:39<00:00,  1.29it/s, est. speed input: 375.55 toks/s, output: 1939.03 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:37<00:00,  1.23s/it, est. speed input: 211.07 toks/s, output: 1522.15 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:33<00:00,  1.20s/it, est. speed input: 226.09 toks/s, output: 1569.20 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:34<00:00,  1.20s/it, est. speed input: 182.96 toks/s, output: 1275.98 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:24<00:00,  1.13s/it, est. speed input: 202.29 toks/s, output: 1327.47 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:11<00:00,  1.03s/it, est. speed input: 276.19 toks/s, output: 1265.65 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:51<00:00,  2.50it/s, est. speed input: 575.99 toks/s, output: 2164.78 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:26<00:00,  1.48it/s, est. speed input: 385.72 toks/s, output: 2339.78 toks/s]
# Processed prompts: 100%|██████████| 128/128 [03:17<00:00,  1.54s/it, est. speed input: 169.36 toks/s, output: 1516.36 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:53<00:00,  2.39it/s, est. speed input: 602.18 toks/s, output: 2329.36 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:36<00:00,  1.22s/it, est. speed input: 222.84 toks/s, output: 1491.65 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:19<00:00,  1.60it/s, est. speed input: 398.23 toks/s, output: 2111.55 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:12<00:00,  1.04s/it, est. speed input: 246.90 toks/s, output: 1160.40 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:25<00:00,  1.13s/it, est. speed input: 203.54 toks/s, output: 1413.15 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:29<00:00,  1.43it/s, est. speed input: 309.07 toks/s, output: 1516.36 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:24<00:00,  1.13s/it, est. speed input: 247.82 toks/s, output: 1332.58 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:23<00:00,  1.12s/it, est. speed input: 249.71 toks/s, output: 1366.41 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:47<00:00,  2.67it/s, est. speed input: 590.10 toks/s, output: 2772.55 toks/s]
# Processed prompts: 100%|██████████| 128/128 [03:09<00:00,  1.48s/it, est. speed input: 180.93 toks/s, output: 1680.87 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:20<00:00,  1.09s/it, est. speed input: 220.63 toks/s, output: 1307.16 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:13<00:00,  1.04s/it, est. speed input: 245.94 toks/s, output: 1322.09 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:16<00:00,  1.67it/s, est. speed input: 399.54 toks/s, output: 2330.96 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:30<00:00,  1.18s/it, est. speed input: 209.27 toks/s, output: 1504.34 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:11<00:00,  1.02s/it, est. speed input: 210.14 toks/s, output: 1257.04 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:25<00:00,  1.14s/it, est. speed input: 203.53 toks/s, output: 1427.16 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:47<00:00,  1.31s/it, est. speed input: 181.72 toks/s, output: 1477.87 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:36<00:00,  1.22s/it, est. speed input: 206.78 toks/s, output: 1439.94 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:12<00:00,  1.04s/it, est. speed input: 223.95 toks/s, output: 1230.33 toks/s]
# Processed prompts: 100%|██████████| 128/128 [03:03<00:00,  1.43s/it, est. speed input: 155.69 toks/s, output: 1536.12 toks/s]
# Processed prompts: 100%|██████████| 128/128 [03:07<00:00,  1.47s/it, est. speed input: 224.14 toks/s, output: 1507.89 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:33<00:00,  1.20s/it, est. speed input: 186.12 toks/s, output: 1537.42 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:06<00:00,  1.02it/s, est. speed input: 216.37 toks/s, output: 1132.66 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:03<00:00,  1.03it/s, est. speed input: 213.14 toks/s, output: 1045.23 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:56<00:00,  1.38s/it, est. speed input: 160.63 toks/s, output: 1596.67 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:26<00:00,  1.15s/it, est. speed input: 216.79 toks/s, output: 1443.22 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:34<00:00,  1.21s/it, est. speed input: 414.52 toks/s, output: 1357.16 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:41<00:00,  1.26s/it, est. speed input: 195.37 toks/s, output: 1602.62 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:45<00:00,  1.29s/it, est. speed input: 189.39 toks/s, output: 1441.29 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:17<00:00,  1.08s/it, est. speed input: 201.62 toks/s, output: 1341.56 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:21<00:00,  1.11s/it, est. speed input: 205.54 toks/s, output: 1420.26 toks/s]
# Processed prompts: 100%|██████████| 128/128 [03:03<00:00,  1.43s/it, est. speed input: 178.92 toks/s, output: 1526.73 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:49<00:00,  1.32s/it, est. speed input: 169.29 toks/s, output: 1632.51 toks/s]
# Processed prompts: 100%|██████████| 128/128 [03:02<00:00,  1.43s/it, est. speed input: 173.19 toks/s, output: 1578.25 toks/s]
# Processed prompts:  99%|█████████▉| 127/128 [00:46<00:01,  1.21s/it, est. speed input: 554.13 toks/s, output: 2377.22 toks/s]

# %%
# print(len(reward_tensor_lst[0]))
import numpy as np
reward_tensors = torch.cat(reward_tensor_lst, dim=0).reshape(-1, n_val_samples).any(dim=-1)
data_sources = np.concatenate(data_source_lst, axis=0).reshape(-1, n_val_samples)[:,0]
data_source_reward = {}
for i in range(reward_tensors.shape[0]):
    data_source = data_sources[i]
    if data_source not in data_source_reward:
        data_source_reward[data_source] = []
    data_source_reward[data_source].append(reward_tensors[i])
metric_dict = {}
average_score = []
for data_source, rewards in data_source_reward.items():
    metric_dict[f'val/test_score/{data_source}'] = np.mean(rewards)
    average_score.append(metric_dict[f'val/test_score/{data_source}'])
metric_dict[f'val/test_score/average'] = np.mean(average_score)
print(metric_dict)

# %%
# for i in range(batch_size):
#     print(f"**************{i}**************")
#     print("ground_truth:", test_batch.non_tensor_batch['reward_model'][i]['ground_truth'])
#     print(output[i].outputs[0].text)
#     print("_______________________________")
