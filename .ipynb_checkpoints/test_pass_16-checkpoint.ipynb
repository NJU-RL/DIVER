# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "7" 

import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from verl.utils.dataset.rl_dataset import RLHFDataset, collate_fn
from torch.utils.data import DataLoader
from vllm import LLM, SamplingParams

# %%
model_path = "/mnt/petrelfs/huzican/R1/rlvr_div/checkpoints/div/pos_rs_0.1-neg_rs_0.01-equ+belu+rule-piecewise_error/actor/global_step_200"

tokenizer = AutoTokenizer.from_pretrained(model_path)
torch.cuda.empty_cache()
base_model = LLM(
    model=model_path,
    tensor_parallel_size=1,
    gpu_memory_utilization=0.85,
    dtype="auto"
)
# Out:
# INFO 08-19 10:50:25 config.py:1450] Downcasting torch.float32 to torch.float16.
# INFO 08-19 10:50:25 llm_engine.py:174] Initializing an LLM engine (v0.5.4) with config: model='/mnt/petrelfs/huzican/R1/rlvr_div/checkpoints/div/pos_rs_0.1-neg_rs_0.01-equ+belu+rule-piecewise_error/actor/global_step_200', speculative_config=None, tokenizer='/mnt/petrelfs/huzican/R1/rlvr_div/checkpoints/div/pos_rs_0.1-neg_rs_0.01-equ+belu+rule-piecewise_error/actor/global_step_200', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, rope_scaling=None, rope_theta=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=16384, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto, quantization_param_path=None, device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='outlines'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None), seed=0, served_model_name=/mnt/petrelfs/huzican/R1/rlvr_div/checkpoints/div/pos_rs_0.1-neg_rs_0.01-equ+belu+rule-piecewise_error/actor/global_step_200, use_v2_block_manager=False, enable_prefix_caching=False)
# INFO 08-19 10:50:26 model_runner.py:720] Starting to load model /mnt/petrelfs/huzican/R1/rlvr_div/checkpoints/div/pos_rs_0.1-neg_rs_0.01-equ+belu+rule-piecewise_error/actor/global_step_200...
# Loading safetensors checkpoint shards:   0% Completed | 0/7 [00:00<?, ?it/s]
# INFO 08-19 10:50:31 model_runner.py:732] Loading model weights took 14.2448 GB
# INFO 08-19 10:50:33 gpu_executor.py:102] # GPU blocks: 59353, # CPU blocks: 4681
# INFO 08-19 10:50:35 model_runner.py:1024] Capturing the model for CUDA graphs. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI.
# INFO 08-19 10:50:35 model_runner.py:1028] CUDA graphs can take additional 1~3 GiB memory per GPU. If you are running out of memory, consider decreasing `gpu_memory_utilization` or enforcing eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# INFO 08-19 10:50:50 model_runner.py:1225] Graph capturing finished in 15 secs.

# %%
val_data_path = "dataset/eval.passn.parquet"
val_dataset = RLHFDataset(parquet_files=val_data_path,
                            tokenizer=tokenizer,
                            prompt_key='prompt',
                            max_prompt_length=1024,
                            filter_prompts=True,
                            return_raw_chat=False,
                            truncation='error')

val_dataloader = DataLoader(dataset=val_dataset,
                            batch_size=8,
                            shuffle=False,
                            drop_last=False,
                            collate_fn=collate_fn)
n_val_samples = 16
# Out:
# original dataset len: 1590
# filter dataset len: 1588

# %%
pad_token_id = tokenizer.pad_token_id
from typing import List
def _pre_process_inputs(pad_token_id, prompt_token_ids: torch.Tensor) -> List[int]:
    # remove the left padding in the prompt token_id
    # pad_token_id = self.llm_engine.tokenizer.pad_token_id if self.llm_engine.tokenizer.pad_token_id is not None else self.llm_engine.tokenizer.eos_token_id
    non_pad_index = torch.nonzero(prompt_token_ids != pad_token_id, as_tuple=False)[0][0]
    token_ids = prompt_token_ids[non_pad_index:].tolist()
    return token_ids

# %%
from deepscaler.globals import THOUGHT_DELIMITER_START, THOUGHT_DELIMITER_END, OAI_RM_MODEL
from deepscaler.rewards import RewardConfig, RewardFn, RewardInput, RewardOutput, RewardType
from deepscaler.rewards.math_reward import RewardMathFn
from verl.div_src.reward_fn import RewardManager
reward_fn = RewardMathFn(RewardConfig)
input = RewardInput(problem="", problem_type=RewardType.MATH, model_response="<think> I am omniscient. </think> The answer is \\boxed{24 + 14*x + (-13)*x^2 - 2*x^3 + x^4}.", ground_truth={"answer": "$x^{4}-2 x^{3}-13 x^{2}+14 x+24$"})
output = reward_fn(input)
print(output.reward)
# THOUGHT_DELIMITER_START + output[0].outputs[0].text
# reward_fn = RewardManager(tokenizer=tokenizer, num_examine=0)
# Out:
# 1.0

# %%
from verl import DataProto
reward_tensor_lst = []
data_source_lst = []
sampling_params = SamplingParams(
    temperature=0.6,
    top_p=1.0,
    max_tokens=8192,
)
val_reward_fn = RewardManager(tokenizer=tokenizer, num_examine=1)
for test_data in val_dataloader:
    
    test_batch = DataProto.from_single_dict(test_data)
    test_batch = test_batch.repeat(repeat_times=n_val_samples, interleave=True)
    idx = test_batch.batch['input_ids']
    batch_size = idx.size(0)

    idx_list = [_pre_process_inputs(pad_token_id, idx[i]) for i in range(batch_size)]
    output = base_model.generate(prompts=None,
                                 sampling_params=sampling_params,
                                 prompt_token_ids=idx_list,
                                 use_tqdm=True)
    data_source_lst.append(test_batch.non_tensor_batch.get('data_source', ['unknown'] * batch_size))
    
    def process_item(response, ground_truth):
        reward_input = RewardInput(problem="", problem_type=RewardType.MATH, model_response=THOUGHT_DELIMITER_START+response, ground_truth={"answer": ground_truth})
        return reward_fn(reward_input).is_correct
    # print(test_batch['reward_model'])
    reward_tensor = torch.zeros(batch_size)
    for i in range(batch_size):
        reward_i = process_item(output[i].outputs[0].text, test_batch.non_tensor_batch['reward_model'][i]['ground_truth'])
        reward_tensor[i] = reward_i
    reward_tensor_lst.append(reward_tensor)
# Out:
# Processed prompts: 100%|██████████| 128/128 [00:34<00:00,  3.73it/s, est. speed input: 898.15 toks/s, output: 2907.28 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:21<00:00,  1.58it/s, est. speed input: 402.80 toks/s, output: 1572.77 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:38<00:00,  1.23s/it, est. speed input: 189.57 toks/s, output: 1282.81 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:03<00:00,  2.00it/s, est. speed input: 426.45 toks/s, output: 1770.99 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:44<00:00,  2.89it/s, est. speed input: 557.94 toks/s, output: 2331.74 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:08<00:00,  1.01s/it, est. speed input: 214.21 toks/s, output: 1131.03 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:39<00:00,  3.23it/s, est. speed input: 617.16 toks/s, output: 2592.06 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:12<00:00,  1.03s/it, est. speed input: 205.57 toks/s, output: 1186.71 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:03<00:00,  1.03it/s, est. speed input: 205.04 toks/s, output: 1042.31 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:33<00:00,  3.77it/s, est. speed input: 735.14 toks/s, output: 2416.25 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:06<00:00,  1.94it/s, est. speed input: 393.84 toks/s, output: 2012.98 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:55<00:00,  2.30it/s, est. speed input: 560.82 toks/s, output: 2164.08 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:40<00:00,  1.26s/it, est. speed input: 201.17 toks/s, output: 1421.71 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:43<00:00,  1.28s/it, est. speed input: 207.03 toks/s, output: 1339.87 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:06<00:00,  1.92it/s, est. speed input: 399.90 toks/s, output: 1687.06 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:21<00:00,  1.58it/s, est. speed input: 351.51 toks/s, output: 1704.08 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:54<00:00,  2.34it/s, est. speed input: 488.72 toks/s, output: 1961.04 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:19<00:00,  1.60it/s, est. speed input: 345.95 toks/s, output: 1690.89 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:12<00:00,  1.03s/it, est. speed input: 230.19 toks/s, output: 1145.88 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:09<00:00,  1.01s/it, est. speed input: 237.77 toks/s, output: 1076.44 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:09<00:00,  1.85it/s, est. speed input: 409.89 toks/s, output: 1692.44 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:11<00:00,  1.03s/it, est. speed input: 265.85 toks/s, output: 1157.09 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:54<00:00,  2.35it/s, est. speed input: 533.24 toks/s, output: 2006.65 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:03<00:00,  2.01it/s, est. speed input: 537.24 toks/s, output: 2211.31 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:02<00:00,  2.04it/s, est. speed input: 400.12 toks/s, output: 2079.00 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:27<00:00,  1.16s/it, est. speed input: 199.10 toks/s, output: 1223.00 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:02<00:00,  1.05it/s, est. speed input: 233.79 toks/s, output: 985.99 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:38<00:00,  3.31it/s, est. speed input: 963.81 toks/s, output: 2669.78 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:01<00:00,  1.05it/s, est. speed input: 233.15 toks/s, output: 1064.12 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:25<00:00,  1.13s/it, est. speed input: 194.48 toks/s, output: 1247.98 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:02<00:00,  1.05it/s, est. speed input: 241.07 toks/s, output: 1053.25 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:08<00:00,  1.00s/it, est. speed input: 211.43 toks/s, output: 1086.27 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:29<00:00,  4.40it/s, est. speed input: 837.50 toks/s, output: 2566.26 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:06<00:00,  1.01it/s, est. speed input: 239.58 toks/s, output: 970.83 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:56<00:00,  1.10it/s, est. speed input: 233.52 toks/s, output: 869.46 toks/s]
# Processed prompts: 100%|██████████| 128/128 [03:01<00:00,  1.41s/it, est. speed input: 189.41 toks/s, output: 1330.25 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:08<00:00,  1.86it/s, est. speed input: 430.67 toks/s, output: 2291.39 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:13<00:00,  1.04s/it, est. speed input: 321.37 toks/s, output: 1202.89 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:15<00:00,  1.70it/s, est. speed input: 344.05 toks/s, output: 1979.56 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:41<00:00,  3.11it/s, est. speed input: 624.63 toks/s, output: 2367.80 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:13<00:00,  1.75it/s, est. speed input: 425.97 toks/s, output: 1824.30 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:17<00:00,  1.66it/s, est. speed input: 339.81 toks/s, output: 1804.90 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:55<00:00,  2.32it/s, est. speed input: 450.90 toks/s, output: 2083.26 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:56<00:00,  2.27it/s, est. speed input: 446.57 toks/s, output: 1923.77 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:24<00:00,  1.13s/it, est. speed input: 201.58 toks/s, output: 1254.48 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:07<00:00,  1.00it/s, est. speed input: 229.00 toks/s, output: 1071.18 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:56<00:00,  2.27it/s, est. speed input: 542.83 toks/s, output: 2101.18 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:58<00:00,  2.19it/s, est. speed input: 525.40 toks/s, output: 2253.05 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:56<00:00,  1.10it/s, est. speed input: 237.61 toks/s, output: 872.17 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:12<00:00,  1.04s/it, est. speed input: 257.58 toks/s, output: 1113.48 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:22<00:00,  1.11s/it, est. speed input: 176.74 toks/s, output: 1203.83 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:11<00:00,  1.79it/s, est. speed input: 369.28 toks/s, output: 1907.56 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:17<00:00,  1.08s/it, est. speed input: 205.69 toks/s, output: 1357.28 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:14<00:00,  1.05s/it, est. speed input: 204.40 toks/s, output: 1144.75 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:16<00:00,  1.07s/it, est. speed input: 187.14 toks/s, output: 1255.57 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:59<00:00,  2.15it/s, est. speed input: 506.93 toks/s, output: 1917.55 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:46<00:00,  2.75it/s, est. speed input: 577.31 toks/s, output: 2316.94 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:43<00:00,  2.93it/s, est. speed input: 687.15 toks/s, output: 2413.32 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:57<00:00,  2.21it/s, est. speed input: 476.97 toks/s, output: 1977.96 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:09<00:00,  1.01s/it, est. speed input: 240.98 toks/s, output: 1161.64 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:15<00:00,  1.06s/it, est. speed input: 216.99 toks/s, output: 1257.55 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:05<00:00,  1.94it/s, est. speed input: 448.35 toks/s, output: 2283.90 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:12<00:00,  1.04s/it, est. speed input: 225.24 toks/s, output: 1239.01 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:44<00:00,  1.29s/it, est. speed input: 205.54 toks/s, output: 1417.91 toks/s]
# Processed prompts: 100%|██████████| 128/128 [03:04<00:00,  1.44s/it, est. speed input: 181.93 toks/s, output: 1528.32 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:46<00:00,  1.30s/it, est. speed input: 196.01 toks/s, output: 1501.35 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:47<00:00,  1.31s/it, est. speed input: 196.54 toks/s, output: 1499.02 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:38<00:00,  1.24s/it, est. speed input: 247.21 toks/s, output: 1514.06 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:42<00:00,  1.27s/it, est. speed input: 200.16 toks/s, output: 1613.47 toks/s]
# Processed prompts: 100%|██████████| 128/128 [03:06<00:00,  1.46s/it, est. speed input: 195.20 toks/s, output: 1470.93 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:35<00:00,  1.33it/s, est. speed input: 393.69 toks/s, output: 2262.82 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:32<00:00,  1.19s/it, est. speed input: 235.95 toks/s, output: 1477.17 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:42<00:00,  1.25it/s, est. speed input: 368.60 toks/s, output: 1922.19 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:50<00:00,  1.33s/it, est. speed input: 216.95 toks/s, output: 1501.42 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:16<00:00,  1.07s/it, est. speed input: 244.98 toks/s, output: 1304.28 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:41<00:00,  1.26it/s, est. speed input: 366.32 toks/s, output: 1891.36 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:44<00:00,  1.28s/it, est. speed input: 202.91 toks/s, output: 1463.32 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:39<00:00,  1.25s/it, est. speed input: 218.10 toks/s, output: 1513.70 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:41<00:00,  1.26s/it, est. speed input: 174.52 toks/s, output: 1217.14 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:30<00:00,  1.17s/it, est. speed input: 194.93 toks/s, output: 1279.21 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:14<00:00,  1.05s/it, est. speed input: 270.38 toks/s, output: 1239.05 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:49<00:00,  2.59it/s, est. speed input: 594.97 toks/s, output: 2236.13 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:24<00:00,  1.52it/s, est. speed input: 397.07 toks/s, output: 2408.65 toks/s]
# Processed prompts: 100%|██████████| 128/128 [03:09<00:00,  1.48s/it, est. speed input: 176.89 toks/s, output: 1583.74 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:51<00:00,  2.47it/s, est. speed input: 620.60 toks/s, output: 2400.59 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:32<00:00,  1.19s/it, est. speed input: 227.95 toks/s, output: 1525.87 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:22<00:00,  1.56it/s, est. speed input: 386.92 toks/s, output: 2051.56 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:12<00:00,  1.04s/it, est. speed input: 246.78 toks/s, output: 1159.84 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:25<00:00,  1.14s/it, est. speed input: 203.29 toks/s, output: 1411.42 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:27<00:00,  1.47it/s, est. speed input: 317.48 toks/s, output: 1557.59 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:21<00:00,  1.10s/it, est. speed input: 253.48 toks/s, output: 1363.03 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:21<00:00,  1.11s/it, est. speed input: 252.49 toks/s, output: 1381.64 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:49<00:00,  2.59it/s, est. speed input: 572.96 toks/s, output: 2692.02 toks/s]
# Processed prompts: 100%|██████████| 128/128 [03:16<00:00,  1.54s/it, est. speed input: 174.88 toks/s, output: 1624.72 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:20<00:00,  1.10s/it, est. speed input: 219.63 toks/s, output: 1301.19 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:13<00:00,  1.04s/it, est. speed input: 245.73 toks/s, output: 1320.96 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:15<00:00,  1.69it/s, est. speed input: 405.66 toks/s, output: 2366.66 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:29<00:00,  1.17s/it, est. speed input: 211.54 toks/s, output: 1520.68 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:12<00:00,  1.04s/it, est. speed input: 207.58 toks/s, output: 1241.76 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:30<00:00,  1.18s/it, est. speed input: 196.51 toks/s, output: 1377.96 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:43<00:00,  1.28s/it, est. speed input: 186.74 toks/s, output: 1518.69 toks/s]
# Processed prompts:  97%|█████████▋| 124/128 [01:45<00:20,  5.17s/it, est. speed input: 296.63 toks/s, output: 1829.79 toks/s]

# %%
# print(len(reward_tensor_lst[0]))
import numpy as np
reward_tensors = torch.cat(reward_tensor_lst, dim=0).reshape(-1, n_val_samples).any(dim=-1)
data_sources = np.concatenate(data_source_lst, axis=0).reshape(-1, n_val_samples)[:,0]
data_source_reward = {}
for i in range(reward_tensors.shape[0]):
    data_source = data_sources[i]
    if data_source not in data_source_reward:
        data_source_reward[data_source] = []
    data_source_reward[data_source].append(reward_tensors[i])
metric_dict = {}
average_score = []
for data_source, rewards in data_source_reward.items():
    metric_dict[f'val/test_score/{data_source}'] = np.mean(rewards)
    average_score.append(metric_dict[f'val/test_score/{data_source}'])
metric_dict[f'val/test_score/average'] = np.mean(average_score)
print(metric_dict)

# %%
# for i in range(batch_size):
#     print(f"**************{i}**************")
#     print("ground_truth:", test_batch.non_tensor_batch['reward_model'][i]['ground_truth'])
#     print(output[i].outputs[0].text)
#     print("_______________________________")
