# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "7" 

import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from verl.utils.dataset.rl_dataset import RLHFDataset, collate_fn
from torch.utils.data import DataLoader
from vllm import LLM, SamplingParams

# %%
# model_path = "/mnt/petrelfs/huzican/R1/rlvr_div/checkpoints/div/pos_rs_0.1-neg_rs_0.01-equ+belu+rule-piecewise_error/actor/global_step_200"
model_path = "/mnt/petrelfs/share_data/huzican/Qwen-2.5-Math-7B-SimpleRL-Zoo"

tokenizer = AutoTokenizer.from_pretrained(model_path)
torch.cuda.empty_cache()
base_model = LLM(
    model=model_path,
    tensor_parallel_size=1,
    gpu_memory_utilization=0.85,
    dtype="auto"
)
# Out:
# INFO 08-28 15:00:45 llm_engine.py:174] Initializing an LLM engine (v0.5.4) with config: model='/mnt/petrelfs/share_data/huzican/Qwen-2.5-Math-7B-SimpleRL-Zero', speculative_config=None, tokenizer='/mnt/petrelfs/share_data/huzican/Qwen-2.5-Math-7B-SimpleRL-Zero', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, rope_scaling=None, rope_theta=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=4096, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto, quantization_param_path=None, device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='outlines'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None), seed=0, served_model_name=/mnt/petrelfs/share_data/huzican/Qwen-2.5-Math-7B-SimpleRL-Zero, use_v2_block_manager=False, enable_prefix_caching=False)
# INFO 08-28 15:00:46 model_runner.py:720] Starting to load model /mnt/petrelfs/share_data/huzican/Qwen-2.5-Math-7B-SimpleRL-Zero...
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# INFO 08-28 15:00:58 model_runner.py:732] Loading model weights took 14.2418 GB
# INFO 08-28 15:00:59 gpu_executor.py:102] # GPU blocks: 60277, # CPU blocks: 4681
# INFO 08-28 15:01:02 model_runner.py:1024] Capturing the model for CUDA graphs. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI.
# INFO 08-28 15:01:02 model_runner.py:1028] CUDA graphs can take additional 1~3 GiB memory per GPU. If you are running out of memory, consider decreasing `gpu_memory_utilization` or enforcing eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# INFO 08-28 15:01:16 model_runner.py:1225] Graph capturing finished in 14 secs.

# %%
val_data_path = "dataset/valid.all.parquet"
val_dataset = RLHFDataset(parquet_files=val_data_path,
                            tokenizer=tokenizer,
                            prompt_key='prompt',
                            max_prompt_length=1024,
                            filter_prompts=True,
                            return_raw_chat=False,
                            truncation='error')

val_dataloader = DataLoader(dataset=val_dataset,
                            batch_size=128,
                            shuffle=False,
                            drop_last=False,
                            collate_fn=collate_fn)
n_val_samples = 1
# Out:
# original dataset len: 6023
# filter dataset len: 6021

# %%
pad_token_id = tokenizer.pad_token_id
from typing import List
def _pre_process_inputs(pad_token_id, prompt_token_ids: torch.Tensor) -> List[int]:
    # remove the left padding in the prompt token_id
    # pad_token_id = self.llm_engine.tokenizer.pad_token_id if self.llm_engine.tokenizer.pad_token_id is not None else self.llm_engine.tokenizer.eos_token_id
    non_pad_index = torch.nonzero(prompt_token_ids != pad_token_id, as_tuple=False)[0][0]
    token_ids = prompt_token_ids[non_pad_index:].tolist()
    return token_ids

# %%
from deepscaler.globals import THOUGHT_DELIMITER_START, THOUGHT_DELIMITER_END, OAI_RM_MODEL
from deepscaler.rewards import RewardConfig, RewardFn, RewardInput, RewardOutput, RewardType
from deepscaler.rewards.math_reward import RewardMathFn
from verl.div_src.reward_fn import RewardManager
reward_fn = RewardMathFn(RewardConfig)
input = RewardInput(problem="", problem_type=RewardType.MATH, model_response="<think> I am omniscient. </think> The answer is \\boxed{24 + 14*x + (-13)*x^2 - 2*x^3 + x^4}.", ground_truth={"answer": "$x^{4}-2 x^{3}-13 x^{2}+14 x+24$"})
output = reward_fn(input)
print(output.reward)
# THOUGHT_DELIMITER_START + output[0].outputs[0].text
# reward_fn = RewardManager(tokenizer=tokenizer, num_examine=0)
# Out:
# 1.0

# %%
from verl import DataProto
reward_tensor_lst = []
data_source_lst = []
sampling_params = SamplingParams(
    temperature=0.6,
    # top_p=1.0,
    max_tokens=8192,
)
val_reward_fn = RewardManager(tokenizer=tokenizer, num_examine=1)
for test_data in val_dataloader:
    
    test_batch = DataProto.from_single_dict(test_data)
    test_batch = test_batch.repeat(repeat_times=n_val_samples, interleave=True)
    idx = test_batch.batch['input_ids']
    batch_size = idx.size(0)

    idx_list = [_pre_process_inputs(pad_token_id, idx[i]) for i in range(batch_size)]
    output = base_model.generate(prompts=None,
                                 sampling_params=sampling_params,
                                 prompt_token_ids=idx_list,
                                 use_tqdm=True)
    data_source_lst.append(test_batch.non_tensor_batch.get('data_source', ['unknown'] * batch_size))
    
    def process_item(response, ground_truth):
        reward_input = RewardInput(problem="", problem_type=RewardType.MATH, model_response=THOUGHT_DELIMITER_START+response, ground_truth={"answer": ground_truth})
        return reward_fn(reward_input).is_correct
    # print(test_batch['reward_model'])
    reward_tensor = torch.zeros(batch_size)
    for i in range(batch_size):
        reward_i = process_item(output[i].outputs[0].text, test_batch.non_tensor_batch['reward_model'][i]['ground_truth'])
        reward_tensor[i] = reward_i
    reward_tensor_lst.append(reward_tensor)
# Out:
# Processed prompts: 100%|██████████| 128/128 [01:15<00:00,  1.70it/s, est. speed input: 374.75 toks/s, output: 1419.57 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:06<00:00,  1.92it/s, est. speed input: 442.74 toks/s, output: 1279.41 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:05<00:00,  1.95it/s, est. speed input: 443.28 toks/s, output: 1300.90 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:07<00:00,  1.91it/s, est. speed input: 429.44 toks/s, output: 1380.64 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:32<00:00,  1.39it/s, est. speed input: 372.31 toks/s, output: 1808.62 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:29<00:00,  1.43it/s, est. speed input: 361.31 toks/s, output: 1695.75 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:33<00:00,  1.37it/s, est. speed input: 345.48 toks/s, output: 1765.90 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:32<00:00,  1.38it/s, est. speed input: 331.79 toks/s, output: 1724.30 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:37<00:00,  1.32it/s, est. speed input: 319.26 toks/s, output: 1774.70 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:32<00:00,  1.38it/s, est. speed input: 376.87 toks/s, output: 1682.32 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:37<00:00,  1.32it/s, est. speed input: 371.99 toks/s, output: 1755.80 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:29<00:00,  1.43it/s, est. speed input: 378.21 toks/s, output: 1720.08 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:33<00:00,  1.37it/s, est. speed input: 439.59 toks/s, output: 1751.12 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:00<00:00,  1.06it/s, est. speed input: 287.06 toks/s, output: 1957.13 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:28<00:00,  1.16s/it, est. speed input: 219.49 toks/s, output: 2080.52 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:48<00:00,  1.18it/s, est. speed input: 319.00 toks/s, output: 1953.81 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:50<00:00,  1.16it/s, est. speed input: 338.06 toks/s, output: 1785.92 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:53<00:00,  1.13it/s, est. speed input: 304.84 toks/s, output: 1863.42 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:15<00:00,  1.70it/s, est. speed input: 453.14 toks/s, output: 1462.60 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:42<00:00,  1.25it/s, est. speed input: 266.61 toks/s, output: 1819.36 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:14<00:00,  1.72it/s, est. speed input: 416.81 toks/s, output: 1453.84 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:33<00:00,  1.37it/s, est. speed input: 349.42 toks/s, output: 1725.18 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:37<00:00,  1.31it/s, est. speed input: 374.83 toks/s, output: 1760.68 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:07<00:00,  1.89it/s, est. speed input: 431.19 toks/s, output: 1368.03 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:19<00:00,  1.61it/s, est. speed input: 392.91 toks/s, output: 1515.16 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:29<00:00,  1.43it/s, est. speed input: 382.40 toks/s, output: 1718.70 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:06<00:00,  1.01it/s, est. speed input: 249.10 toks/s, output: 2007.25 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:46<00:00,  1.20it/s, est. speed input: 428.62 toks/s, output: 1950.03 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:57<00:00,  2.24it/s, est. speed input: 504.09 toks/s, output: 1262.27 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:09<00:00,  1.85it/s, est. speed input: 394.34 toks/s, output: 1459.84 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:09<00:00,  1.84it/s, est. speed input: 373.10 toks/s, output: 1369.26 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:42<00:00,  1.24it/s, est. speed input: 292.29 toks/s, output: 2011.36 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:35<00:00,  1.33it/s, est. speed input: 356.32 toks/s, output: 1878.56 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:00<00:00,  2.13it/s, est. speed input: 536.97 toks/s, output: 1109.36 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:08<00:00,  1.88it/s, est. speed input: 450.06 toks/s, output: 1391.91 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:25<00:00,  1.49it/s, est. speed input: 377.10 toks/s, output: 1764.27 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:14<00:00,  1.73it/s, est. speed input: 400.60 toks/s, output: 1620.65 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:24<00:00,  1.52it/s, est. speed input: 397.83 toks/s, output: 1624.47 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:13<00:00,  1.73it/s, est. speed input: 400.95 toks/s, output: 1538.74 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:23<00:00,  1.54it/s, est. speed input: 340.68 toks/s, output: 1747.32 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:20<00:00,  1.59it/s, est. speed input: 375.30 toks/s, output: 1722.16 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:51<00:00,  1.15it/s, est. speed input: 329.10 toks/s, output: 2028.96 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:15<00:00,  1.06s/it, est. speed input: 269.02 toks/s, output: 2017.15 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:08<00:00,  1.00s/it, est. speed input: 224.81 toks/s, output: 2016.52 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:50<00:00,  1.16it/s, est. speed input: 388.15 toks/s, output: 1925.38 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:44<00:00,  1.23it/s, est. speed input: 332.43 toks/s, output: 1843.90 toks/s]
# Processed prompts: 100%|██████████| 128/128 [02:24<00:00,  1.13s/it, est. speed input: 250.95 toks/s, output: 2118.03 toks/s]
# Processed prompts: 100%|██████████| 5/5 [00:51<00:00, 10.28s/it, est. speed input: 22.65 toks/s, output: 351.37 toks/s]

# %%
# print(len(reward_tensor_lst[0]))
import numpy as np
reward_tensors = torch.cat(reward_tensor_lst, dim=0).reshape(-1, n_val_samples).any(dim=-1)
data_sources = np.concatenate(data_source_lst, axis=0).reshape(-1, n_val_samples)[:,0]
data_source_reward = {}
for i in range(reward_tensors.shape[0]):
    data_source = data_sources[i]
    if data_source not in data_source_reward:
        data_source_reward[data_source] = []
    data_source_reward[data_source].append(reward_tensors[i])
metric_dict = {}
average_score = []
for data_source, rewards in data_source_reward.items():
    metric_dict[f'val/test_score/{data_source}'] = np.mean(rewards)
    average_score.append(metric_dict[f'val/test_score/{data_source}'])
metric_dict[f'val/test_score/average'] = np.mean(average_score)
print(metric_dict)
# Out:
# {'val/test_score/math': 0.754, 'val/test_score/olympiad_bench': 0.3209509658246657, 'val/test_score/minerva': 0.20588235294117646, 'val/test_score/aime': 0.23854166666666668, 'val/test_score/amc': 0.5496987951807228, 'val/test_score/aime25': 0.07291666666666667, 'val/test_score/average': 0.356998407879983}

# %%
# for i in range(batch_size):
#     print(f"**************{i}**************")
#     print("ground_truth:", test_batch.non_tensor_batch['reward_model'][i]['ground_truth'])
#     print(output[i].outputs[0].text)
#     print("_______________________________")
