# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "7" 

import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from verl.utils.dataset.rl_dataset import RLHFDataset, collate_fn
from torch.utils.data import DataLoader
from vllm import LLM, SamplingParams

# %%
# model_path = "/mnt/petrelfs/huzican/R1/rlvr_div/checkpoints/div/pos_rs_0.1-neg_rs_0.01-equ+belu+rule-piecewise_error/actor/global_step_200"
model_path = "/mnt/petrelfs/share_data/huzican/Qwen-2.5-Math-7B-SimpleRL-Zoo"

tokenizer = AutoTokenizer.from_pretrained(model_path)
torch.cuda.empty_cache()
base_model = LLM(
    model=model_path,
    tensor_parallel_size=1,
    gpu_memory_utilization=0.85,
    dtype="auto"
)
# Out:
# INFO 08-28 16:32:25 config.py:1450] Downcasting torch.float32 to torch.float16.
# INFO 08-28 16:32:25 llm_engine.py:174] Initializing an LLM engine (v0.5.4) with config: model='/mnt/petrelfs/share_data/huzican/Qwen-2.5-Math-7B-SimpleRL-Zoo', speculative_config=None, tokenizer='/mnt/petrelfs/share_data/huzican/Qwen-2.5-Math-7B-SimpleRL-Zoo', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, rope_scaling=None, rope_theta=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=4096, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto, quantization_param_path=None, device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='outlines'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None), seed=0, served_model_name=/mnt/petrelfs/share_data/huzican/Qwen-2.5-Math-7B-SimpleRL-Zoo, use_v2_block_manager=False, enable_prefix_caching=False)
# INFO 08-28 16:32:25 model_runner.py:720] Starting to load model /mnt/petrelfs/share_data/huzican/Qwen-2.5-Math-7B-SimpleRL-Zoo...
# Loading safetensors checkpoint shards:   0% Completed | 0/7 [00:00<?, ?it/s]
# INFO 08-28 16:32:38 model_runner.py:732] Loading model weights took 14.2418 GB
# INFO 08-28 16:32:39 gpu_executor.py:102] # GPU blocks: 60277, # CPU blocks: 4681
# INFO 08-28 16:32:42 model_runner.py:1024] Capturing the model for CUDA graphs. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI.
# INFO 08-28 16:32:42 model_runner.py:1028] CUDA graphs can take additional 1~3 GiB memory per GPU. If you are running out of memory, consider decreasing `gpu_memory_utilization` or enforcing eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# INFO 08-28 16:32:56 model_runner.py:1225] Graph capturing finished in 14 secs.

# %%
val_data_path = "dataset/valid.all.parquet"
val_dataset = RLHFDataset(parquet_files=val_data_path,
                            tokenizer=tokenizer,
                            prompt_key='prompt',
                            max_prompt_length=1024,
                            filter_prompts=True,
                            return_raw_chat=False,
                            truncation='error')

val_dataloader = DataLoader(dataset=val_dataset,
                            batch_size=128,
                            shuffle=False,
                            drop_last=False,
                            collate_fn=collate_fn)
n_val_samples = 1
# Out:
# original dataset len: 6023
# filter dataset len: 6021

# %%
pad_token_id = tokenizer.pad_token_id
from typing import List
def _pre_process_inputs(pad_token_id, prompt_token_ids: torch.Tensor) -> List[int]:
    # remove the left padding in the prompt token_id
    # pad_token_id = self.llm_engine.tokenizer.pad_token_id if self.llm_engine.tokenizer.pad_token_id is not None else self.llm_engine.tokenizer.eos_token_id
    non_pad_index = torch.nonzero(prompt_token_ids != pad_token_id, as_tuple=False)[0][0]
    token_ids = prompt_token_ids[non_pad_index:].tolist()
    return token_ids

# %%
from deepscaler.globals import THOUGHT_DELIMITER_START, THOUGHT_DELIMITER_END, OAI_RM_MODEL
from deepscaler.rewards import RewardConfig, RewardFn, RewardInput, RewardOutput, RewardType
from deepscaler.rewards.math_reward import RewardMathFn
from verl.div_src.reward_fn import RewardManager
reward_fn = RewardMathFn(RewardConfig)
input = RewardInput(problem="", problem_type=RewardType.MATH, model_response="<think> I am omniscient. </think> The answer is \\boxed{24 + 14*x + (-13)*x^2 - 2*x^3 + x^4}.", ground_truth={"answer": "$x^{4}-2 x^{3}-13 x^{2}+14 x+24$"})
output = reward_fn(input)
print(output.reward)
# THOUGHT_DELIMITER_START + output[0].outputs[0].text
# reward_fn = RewardManager(tokenizer=tokenizer, num_examine=0)
# Out:
# 1.0

# %%
from verl import DataProto
reward_tensor_lst = []
data_source_lst = []
sampling_params = SamplingParams(
    temperature=0.6,
    # top_p=1.0,
    max_tokens=8192,
)
val_reward_fn = RewardManager(tokenizer=tokenizer, num_examine=1)
for test_data in val_dataloader:
    
    test_batch = DataProto.from_single_dict(test_data)
    test_batch = test_batch.repeat(repeat_times=n_val_samples, interleave=True)
    idx = test_batch.batch['input_ids']
    batch_size = idx.size(0)

    idx_list = [_pre_process_inputs(pad_token_id, idx[i]) for i in range(batch_size)]
    output = base_model.generate(prompts=None,
                                 sampling_params=sampling_params,
                                 prompt_token_ids=idx_list,
                                 use_tqdm=True)
    data_source_lst.append(test_batch.non_tensor_batch.get('data_source', ['unknown'] * batch_size))
    
    def process_item(response, ground_truth):
        reward_input = RewardInput(problem="", problem_type=RewardType.MATH, model_response=THOUGHT_DELIMITER_START+response, ground_truth={"answer": ground_truth})
        return reward_fn(reward_input).is_correct
    # print(test_batch['reward_model'])
    reward_tensor = torch.zeros(batch_size)
    for i in range(batch_size):
        reward_i = process_item(output[i].outputs[0].text, test_batch.non_tensor_batch['reward_model'][i]['ground_truth'])
        reward_tensor[i] = reward_i
    reward_tensor_lst.append(reward_tensor)
# Out:
# Processed prompts: 100%|██████████| 128/128 [01:02<00:00,  2.04it/s, est. speed input: 448.36 toks/s, output: 1313.17 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:05<00:00,  1.95it/s, est. speed input: 451.37 toks/s, output: 1309.81 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:45<00:00,  2.83it/s, est. speed input: 643.12 toks/s, output: 1813.62 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:05<00:00,  1.95it/s, est. speed input: 437.95 toks/s, output: 1375.81 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:11<00:00,  1.79it/s, est. speed input: 480.01 toks/s, output: 1788.58 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:04<00:00,  1.97it/s, est. speed input: 498.32 toks/s, output: 1655.57 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:06<00:00,  1.92it/s, est. speed input: 484.91 toks/s, output: 1657.71 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:06<00:00,  1.92it/s, est. speed input: 459.81 toks/s, output: 1657.23 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:08<00:00,  1.86it/s, est. speed input: 451.72 toks/s, output: 1663.29 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:01<00:00,  2.08it/s, est. speed input: 568.37 toks/s, output: 1443.25 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:59<00:00,  2.17it/s, est. speed input: 612.41 toks/s, output: 1379.80 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:11<00:00,  1.78it/s, est. speed input: 470.62 toks/s, output: 1767.71 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:07<00:00,  1.90it/s, est. speed input: 608.90 toks/s, output: 1787.50 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:26<00:00,  1.48it/s, est. speed input: 400.67 toks/s, output: 1925.63 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:36<00:00,  1.32it/s, est. speed input: 338.43 toks/s, output: 2275.22 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:35<00:00,  1.34it/s, est. speed input: 362.02 toks/s, output: 2183.48 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:32<00:00,  1.39it/s, est. speed input: 402.86 toks/s, output: 2073.27 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:26<00:00,  1.47it/s, est. speed input: 397.30 toks/s, output: 2041.70 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:11<00:00,  1.78it/s, est. speed input: 476.39 toks/s, output: 1686.33 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:08<00:00,  1.86it/s, est. speed input: 395.90 toks/s, output: 1789.50 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:04<00:00,  2.00it/s, est. speed input: 483.77 toks/s, output: 1622.10 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:14<00:00,  1.71it/s, est. speed input: 438.07 toks/s, output: 1863.50 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:12<00:00,  1.78it/s, est. speed input: 507.87 toks/s, output: 1814.30 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:02<00:00,  2.04it/s, est. speed input: 465.05 toks/s, output: 1515.99 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:13<00:00,  1.73it/s, est. speed input: 424.19 toks/s, output: 1881.46 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:03<00:00,  2.02it/s, est. speed input: 539.80 toks/s, output: 1597.03 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:28<00:00,  1.44it/s, est. speed input: 354.61 toks/s, output: 2135.64 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:17<00:00,  1.64it/s, est. speed input: 587.29 toks/s, output: 2002.35 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:02<00:00,  2.05it/s, est. speed input: 461.31 toks/s, output: 1577.52 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:04<00:00,  1.99it/s, est. speed input: 423.31 toks/s, output: 1630.19 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:03<00:00,  2.02it/s, est. speed input: 408.98 toks/s, output: 1559.17 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:14<00:00,  1.71it/s, est. speed input: 402.13 toks/s, output: 1976.98 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:17<00:00,  1.65it/s, est. speed input: 439.79 toks/s, output: 2008.30 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:58<00:00,  2.20it/s, est. speed input: 555.58 toks/s, output: 1267.12 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:59<00:00,  2.13it/s, est. speed input: 512.22 toks/s, output: 1419.36 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:12<00:00,  1.77it/s, est. speed input: 446.46 toks/s, output: 1776.13 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:06<00:00,  1.92it/s, est. speed input: 445.33 toks/s, output: 1763.29 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:03<00:00,  2.01it/s, est. speed input: 525.08 toks/s, output: 1608.19 toks/s]
# Processed prompts: 100%|██████████| 128/128 [00:48<00:00,  2.64it/s, est. speed input: 609.68 toks/s, output: 2015.21 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:16<00:00,  1.68it/s, est. speed input: 373.21 toks/s, output: 1931.28 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:08<00:00,  1.88it/s, est. speed input: 444.55 toks/s, output: 1849.93 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:23<00:00,  1.53it/s, est. speed input: 438.64 toks/s, output: 2134.91 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:31<00:00,  1.41it/s, est. speed input: 400.48 toks/s, output: 2160.80 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:12<00:00,  1.76it/s, est. speed input: 396.59 toks/s, output: 1979.74 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:15<00:00,  1.69it/s, est. speed input: 563.50 toks/s, output: 1981.38 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:12<00:00,  1.77it/s, est. speed input: 478.44 toks/s, output: 1823.57 toks/s]
# Processed prompts: 100%|██████████| 128/128 [01:49<00:00,  1.17it/s, est. speed input: 330.59 toks/s, output: 2286.79 toks/s]
# Processed prompts: 100%|██████████| 5/5 [00:45<00:00,  9.19s/it, est. speed input: 25.37 toks/s, output: 206.35 toks/s]

# %%
# print(len(reward_tensor_lst[0]))
import numpy as np
reward_tensors = torch.cat(reward_tensor_lst, dim=0).reshape(-1, n_val_samples).any(dim=-1)
data_sources = np.concatenate(data_source_lst, axis=0).reshape(-1, n_val_samples)[:,0]
data_source_reward = {}
for i in range(reward_tensors.shape[0]):
    data_source = data_sources[i]
    if data_source not in data_source_reward:
        data_source_reward[data_source] = []
    data_source_reward[data_source].append(reward_tensors[i])
metric_dict = {}
average_score = []
for data_source, rewards in data_source_reward.items():
    metric_dict[f'val/test_score/{data_source}'] = np.mean(rewards)
    average_score.append(metric_dict[f'val/test_score/{data_source}'])
metric_dict[f'val/test_score/average'] = np.mean(average_score)
print(metric_dict)
# Out:
# {'val/test_score/math': 0.762, 'val/test_score/olympiad_bench': 0.4101040118870728, 'val/test_score/minerva': 0.27205882352941174, 'val/test_score/aime': 0.2520833333333333, 'val/test_score/amc': 0.5760542168674698, 'val/test_score/aime25': 0.11979166666666667, 'val/test_score/average': 0.39868200871399234}

# %%
# for i in range(batch_size):
#     print(f"**************{i}**************")
#     print("ground_truth:", test_batch.non_tensor_batch['reward_model'][i]['ground_truth'])
#     print(output[i].outputs[0].text)
#     print("_______________________________")
