# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
import pandas as pd
train_path = "dataset/aime25.parquet"
df = pd.read_parquet(train_path)
print(len(df))
df.iloc[20]
# Out:
# 30
# data_source                                                aime25
# prompt          [{'content': 'Circle $\omega_1$ with radius 6 ...
# ability                                                      math
# reward_model             {'ground_truth': '293', 'style': 'rule'}
# extra_info                      {'index': 20, 'split': 'default'}
# Name: 665, dtype: object
